# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns

# %matplotlib inline

datos = np.random.rand(100)

mpl.pyplot.hist(datos)
# Out:
# (array([ 5.,  8.,  9., 13., 11.,  6., 17., 12.,  9., 10.]),
#  array([0.00265377, 0.10204575, 0.20143774, 0.30082972, 0.4002217 ,
#         0.49961368, 0.59900567, 0.69839765, 0.79778963, 0.89718161,
#         0.99657359]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(datos)

# %%
sns.distplot(datos, color="green")

# %%
datos2 = np.random.rand(80)
mpl.pyplot.hist(datos2, color="red")
# Out:
# (array([10., 11., 10.,  6.,  5.,  5., 11.,  7.,  8.,  7.]),
#  array([0.00144812, 0.09946952, 0.19749092, 0.29551233, 0.39353373,
#         0.49155513, 0.58957653, 0.68759794, 0.78561934, 0.88364074,
#         0.98166214]),
#  <a list of 10 Patch objects>)

# %%
mpl.pyplot.hist(datos,color="green", bins=20 ,density=True)
mpl.pyplot.hist(datos2,color="blue", bins=20, density=True)
# Out:
# (array([1.78532438, 0.76513902, 2.04037073, 0.76513902, 0.76513902,
#         1.78532438, 0.76513902, 0.76513902, 1.02018536, 0.25504634,
#         1.02018536, 0.25504634, 1.2752317 , 1.53027804, 1.53027804,
#         0.25504634, 0.25504634, 1.78532438, 1.2752317 , 0.51009268]),
#  array([0.00144812, 0.05045882, 0.09946952, 0.14848022, 0.19749092,
#         0.24650163, 0.29551233, 0.34452303, 0.39353373, 0.44254443,
#         0.49155513, 0.54056583, 0.58957653, 0.63858724, 0.68759794,
#         0.73660864, 0.78561934, 0.83463004, 0.88364074, 0.93265144,
#         0.98166214]),
#  <a list of 20 Patch objects>)

# %%
datos3 = np.random.rand(100)
sns.jointplot(datos,datos3)

# %%
sns.jointplot(datos,datos3, kind="hex")
